# %% [markdown]
# <div>
# <img src="https://drive.google.com/uc?export=view&id=1vK33e_EqaHgBHcbRV_m38hx6IkG0blK_" width="350"/>
# </div>
#
# #**Artificial Intelligence - MSc**
#
# ##***CS6462 - Probabilistic and Explainable AI***
#
# ###CS6462_PracticeLab-9.1
#
# *This practice address the principles of probability calculus,
# use probabilistic models to solve optimization problems, and it is in line with the learning outcomes to demonstrate an ability to formulate machine learning and other data exploration algorithms as optimization algorithms.*

# %% [markdown]
# #Grammatical Evolution

# %%
# Clone temporally PonyGE into your 'content' Colab directory
# !git clone https://github.com/PonyGE/PonyGE2.git
# Out:
# Cloning into 'PonyGE2'...
# remote: Enumerating objects: 5774, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 5774 (delta 0), reused 10 (delta 0), pack-reused 5736
# Receiving objects: 100% (5774/5774), 5.57 MiB | 2.84 MiB/s, done.
# Resolving deltas: 100% (4069/4069), done.
# Updating files: 100% (268/268), done.

# %%
# Portable way of using operating system-dependent functionality. 
import os
# !pwd
# Out:
# /mnt/c/ubuntu20.04/masters_ai_ul/thesis/map_elites-grammatical_evolution/topic_grammatical_evolution/PolyGE

# %%
# Built-in magic command: %cd
# to change the current working directory.
# %cd PonyGE2/src
# Out:
# /mnt/c/ubuntu20.04/masters_ai_ul/thesis/map_elites-grammatical_evolution/topic_grammatical_evolution/PolyGE/PonyGE2/src

# %%
# run regression example
# and save results in the example_dir

# !python3 ponyge.py --experiment_name example_dir
# Out:
# Start:	 2021-05-08 15:24:52.941725
#
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# Evolution: 98% complete
#
# Best:
#   Fitness:	 0.18247686677058733
#   Phenotype: np.sin(plog(np.sin(psqrt(x[3])*np.tanh(pdiv(x[0],np.sin(pdiv(np.sin(np.tanh(np.sin(plog(np.tanh(x[0]))))),psqrt(psqrt(np.sin(plog(psqrt(pdiv(np.exp(plog(np.sin(np.sin(plog(np.tanh(pdiv(x[4],plog(psqrt(np.sin(psqrt(x[3])))))+x[3])))))),np.tanh(np.tanh(x[1]*np.sin(np.sin(np.exp(np.tanh(plog(plog(np.sin(x[1]))))))))))))))-np.sin(psqrt(psqrt(85.15)))))*x[3]))))))
# ...

# %%
# Read the regression.txt
# to see all parameters

filename = "../parameters/regression.txt"

# %%
# Show the parameters we can use

with open(filename, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# CACHE:                  True
# CODON_SIZE:             100000
# CROSSOVER:              variable_onepoint
# CROSSOVER_PROBABILITY:  0.75
# DATASET_TRAIN:          Vladislavleva4/Train.txt
# DATASET_TEST:           Vladislavleva4/Test.txt
# DEBUG:                  False
# ERROR_METRIC:           mse
# GENERATIONS:            50
# MAX_GENOME_LENGTH:      500
# GRAMMAR_FILE:           supervised_learning/Vladislavleva4.bnf
# INITIALISATION:         PI_grow
# INVALID_SELECTION:      False
# MAX_INIT_TREE_DEPTH:    10
# MAX_TREE_DEPTH:         17
# MUTATION:               int_flip_per_codon
# POPULATION_SIZE:        500
# FITNESS_FUNCTION:       supervised_learning.regression
# REPLACEMENT:            generational
# SELECTION:              tournament
# TOURNAMENT_SIZE:        2
# VERBOSE:                False

# %%
# Verify if the file is closed

file1.closed
# Out:
# True

# %%
# run regression example
# with some parameters

# !python ponyge.py --parameters regression.txt --verbose --population_size 100 --fitness_function supervised_learning.regression --grammar_file supervised_learning/Vladislavleva4.bnf
# Out:
# Start:	 2021-05-03 00:05:49.615026
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# ______
#
#   ave_fitness : 	 1.3760876773738093e+64
#   ave_genome_length : 	 25.06
#   ave_tree_depth : 	 6.45
#   ave_tree_nodes : 	 23.28
#   ave_used_codons : 	 16.85
#   best_fitness : 	 0.04528747823331862
#   gen : 	 0
#   invalids : 	 0
#   max_genome_length : 	 130
# ...
